# %%
import pandas as pd

# %%
financial_data = pd.read_csv('../data/cleaned_data.csv')
financial_data.head()
# Out:
# C:\Users\saigi\AppData\Local\Temp\ipykernel_16868\3380950219.py:1: DtypeWarning: Columns (48,52,54,60,64,67,71,73,74,75,77,78,79,80,81,82,83,84,85,86,87,88,89,147,150,152,157,160,165,166,168,171,173,174,176,177,178,180,181,182,183,184,185,186,187,188,189,190,191) have mixed types. Specify dtype option on import or set low_memory=False.
#   financial_data = pd.read_csv('../data/cleaned_data.csv')
#    Unnamed: 0                                           pre_text  \
# 0           0  26 | 2009 annual report in fiscal 2008 , reven...
# 1           1  26 | 2009 annual report in fiscal 2008 , reven...
# 2           2  26 | 2009 annual report in fiscal 2008 , reven...
# 3           3  26 | 2009 annual report in fiscal 2008 , reven...
# 4           4  substantially all of the goodwill and other in...
#
#                                            post_text               filename  \
# 0  year ended june 30 , cash provided by operatio...  JKHY/2009/page_28.pdf
# 1  year ended june 30 , cash provided by operatio...  JKHY/2009/page_28.pdf
# 2  year ended june 30 , cash provided by operatio...  JKHY/2009/page_28.pdf
# 3  year ended june 30 , cash provided by operatio...  JKHY/2009/page_28.pdf
# 4  the above unaudited pro forma financial inform...  RSG/2008/page_114.pdf
#
#                                            table_ori  \
# 0  [['', 'Year ended June 30, 2009'], ['2008', '2...
# 1  [['', 'Year ended June 30, 2009'], ['2008', '2...
# 2  [['', 'Year ended June 30, 2009'], ['2008', '2...
# 3  [['', 'Year ended June 30, 2009'], ['2008', '2...
# 4  [['', 'Year Ended December 31, 2008 (Unaudited...
#
#                                                table  \
# 0  [['2008', 'year ended june 30 2009 2008', 'yea...
# 1  [['2008', 'year ended june 30 2009 2008', 'yea...
# 2  [['2008', 'year ended june 30 2009 2008', 'yea...
# 3  [['2008', 'year ended june 30 2009 2008', 'yea...
# 4  [['', 'year ended december 31 2008 ( unaudited...
#
#                                                   qa  \
# 0  {'question': 'what was the percentage change i...
# 1  {'question': 'what was the percentage change i...
# 2  {'question': 'what was the percentage change i...
# 3  {'question': 'what was the percentage change i...
# 4  {'question': 'what was the percent of the grow...
#
#                                  id  \
# 0  Single_JKHY/2009/page_28.pdf-3_0
# 1  Single_JKHY/2009/page_28.pdf-3_1
# 2  Single_JKHY/2009/page_28.pdf-3_2
# 3  Single_JKHY/2009/page_28.pdf-3_3
# 4  Single_RSG/2008/page_114.pdf-2_0
#
#                                           annotation qa_0  ...  \
# 0  {'amt_table': "<table class='wikitable'><tr><t...  NaN  ...
# 1  {'amt_table': "<table class='wikitable'><tr><t...  NaN  ...
# 2  {'amt_table': "<table class='wikitable'><tr><t...  NaN  ...
# 3  {'amt_table': "<table class='wikitable'><tr><t...  NaN  ...
# 4  {'amt_table': "<table class='wikitable'><tr><t...  NaN  ...
#
#   gold_ind.text_45 gold_ind.text_211 gold_ind.text_-1 gold_ind.text_49  \
# 0              NaN               NaN              NaN              NaN
# 1              NaN               NaN              NaN              NaN
# 2              NaN               NaN              NaN              NaN
# 3              NaN               NaN              NaN              NaN
# 4              NaN               NaN              NaN              NaN
#
#   gold_ind.text_73 gold_ind.text_76 gold_ind.text_63 gold_ind.text_94  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#   gold_ind.text_96 gold_ind.text_58
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN
#
# [5 rows x 192 columns]

# %%
financial_data_filter = financial_data[['pre_text','post_text','question','answer']]
financial_data_filter.head()
# Out:
#                                             pre_text  \
# 0  26 | 2009 annual report in fiscal 2008 , reven...
# 1  26 | 2009 annual report in fiscal 2008 , reven...
# 2  26 | 2009 annual report in fiscal 2008 , reven...
# 3  26 | 2009 annual report in fiscal 2008 , reven...
# 4  substantially all of the goodwill and other in...
#
#                                            post_text  \
# 0  year ended june 30 , cash provided by operatio...
# 1  year ended june 30 , cash provided by operatio...
# 2  year ended june 30 , cash provided by operatio...
# 3  year ended june 30 , cash provided by operatio...
# 4  the above unaudited pro forma financial inform...
#
#                                             question answer
# 0  what was the percentage change in the net cash...  14.1%
# 1  what was the percentage change in the net cash...  14.1%
# 2  what was the percentage change in the net cash...  14.1%
# 3  what was the percentage change in the net cash...  14.1%
# 4  what was the percent of the growth in the reve...   1.3%

# %%
from langchain.embeddings import OllamaEmbeddings
from langchain.vectorstores import FAISS

embeddings = OllamaEmbeddings(model='mxbai-embed-large')
vectorstore = FAISS.from_texts(financial_data_filter['pre_text'] + financial_data_filter['post_text'], embeddings)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 5
#       2 from langchain.vectorstores import FAISS
#       4 embeddings = OllamaEmbeddings(model='mxbai-embed-large')
# ----> 5 vectorstore = FAISS.from_texts(financial_data_filter['pre_text'] + financial_data_filter['post_text'], embeddings)
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:1041, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1014 @classmethod
#    1015 def from_texts(
#    1016     cls,
#    (...)
#    1021     **kwargs: Any,
#    1022 ) -> FAISS:
#    1023     """Construct FAISS wrapper from raw documents.
#    1024
#    1025     This is a user friendly interface that:
#    (...)
#    1039             faiss = FAISS.from_texts(texts, embeddings)
#    1040     """
# -> 1041     embeddings = embedding.embed_documents(texts)
#    1042     return cls.__from(
#    1043         texts,
#    1044         embeddings,
#    (...)
#    1048         **kwargs,
#    1049     )
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_community\embeddings\ollama.py:209, in OllamaEmbeddings.embed_documents(self, texts)
#     200 """Embed documents using an Ollama deployed embedding model.
#     201
#     202 Args:
#    (...)
#     206     List of embeddings, one for each text.
#     207 """
#     208 instruction_pairs = [f"{self.embed_instruction}{text}" for text in texts]
# --> 209 embeddings = self._embed(instruction_pairs)
#     210 return embeddings
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_community\embeddings\ollama.py:197, in OllamaEmbeddings._embed(self, input)
#     195 else:
#     196     iter_ = input
# --> 197 return [self._process_emb_response(prompt) for prompt in iter_]
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_community\embeddings\ollama.py:162, in OllamaEmbeddings._process_emb_response(self, input)
#     156 headers = {
#     157     "Content-Type": "application/json",
#     158     **(self.headers or {}),
#     159 }
#     161 try:
# --> 162     res = requests.post(
#     163         f"{self.base_url}/api/embeddings",
#     164         headers=headers,
#     165         json={"model": self.model, "prompt": input, **self._default_params},
#     166     )
#     167 except requests.exceptions.RequestException as e:
#     168     raise ValueError(f"Error raised by inference endpoint: {e}")
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\urllib3\connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#     509 except BrokenPipeError:
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\urllib3\connection.py:398, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     396 for header, value in headers.items():
#     397     self.putheader(header, value)
# --> 398 self.endheaders()
#     400 # If we're given a body we start sending that in chunks.
#     401 if chunks is not None:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1329 else:
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1089 msg = b"\r\n".join(self._buffer)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#    1096     if hasattr(message_body, 'read'):
#    1097         # Let file-like take precedence over byte-like.  This
#    1098         # is needed to allow the current position of mmap'ed
#    1099         # files to be taken into account.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1035, in HTTPConnection.send(self, data)
#    1033 if self.sock is None:
#    1034     if self.auto_open:
# -> 1035         self.connect()
#    1036     else:
#    1037         raise NotConnected()
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\urllib3\connection.py:236, in HTTPConnection.connect(self)
#     235 def connect(self) -> None:
# --> 236     self.sock = self._new_conn()
#     237     if self._tunnel_host:
#     238         # If we're tunneling it means we're connected to our proxy.
#     239         self._has_connected_to_proxy = True
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     191 """Establish a socket connection and set nodelay settings on it.
#     192
#     193 :return: New socket connection.
#     194 """
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#     203     raise NameResolutionError(self.host, self, e) from e
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\urllib3\util\connection.py:81, in create_connection(address, timeout, source_address, socket_options)
#      79         err = _
#      80         if sock is not None:
# ---> 81             sock.close()
#      83 if err is not None:
#      84     try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:501, in socket.close(self)
#     497 def _real_close(self, _ss=_socket.socket):
#     498     # This function should not reference any globals. See issue #808164.
#     499     _ss.close(self)
# --> 501 def close(self):
#     502     # This function should not reference any globals. See issue #808164.
#     503     self._closed = True
#     504     if self._io_refs <= 0:
#
# KeyboardInterrupt:

# %%
from langchain.chains import RetrievalQA
from langchain.llms import Ollama

llm = Ollama(model="llama")
qa_chain = RetrievalQA.from_chain_type(llm, retriever=vectorstore.as_retriever(), chain_type="stuff")

# User question
question = "What was the percentage change in the net cash?"

result = qa_chain.run(question)
print(result)
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 agent.invoke("what was the percentage change in the net cash from operating activities from 2008 to 2009?")
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain\chains\base.py:164, in Chain.invoke(self, input, config, **kwargs)
#     162 except BaseException as e:
#     163     run_manager.on_chain_error(e)
# --> 164     raise e
#     165 run_manager.on_chain_end(outputs)
#     167 if include_run_info:
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain\chains\base.py:154, in Chain.invoke(self, input, config, **kwargs)
#     151 try:
#     152     self._validate_inputs(inputs)
#     153     outputs = (
# --> 154         self._call(inputs, run_manager=run_manager)
#     155         if new_arg_supported
#     156         else self._call(inputs)
#     157     )
#     159     final_outputs: Dict[str, Any] = self.prep_outputs(
#     160         inputs, outputs, return_only_outputs
#     161     )
#     162 except BaseException as e:
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain\agents\agent.py:1625, in AgentExecutor._call(self, inputs, run_manager)
#    1623 # We now enter the agent loop (until it returns something).
#    1624 while self._should_continue(iterations, time_elapsed):
# -> 1625     next_step_output = self._take_next_step(
#    1626         name_to_tool_map,
#    1627         color_mapping,
#    1628         inputs,
#    1629         intermediate_steps,
#    1630         run_manager=run_manager,
#    1631     )
#    1632     if isinstance(next_step_output, AgentFinish):
#    1633         return self._return(
#    1634             next_step_output, intermediate_steps, run_manager=run_manager
#    1635         )
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain\agents\agent.py:1331, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1322 def _take_next_step(
#    1323     self,
#    1324     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1328     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1329 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1330     return self._consume_next_step(
# -> 1331         [
#    1332             a
#    1333             for a in self._iter_next_step(
#    1334                 name_to_tool_map,
#    1335                 color_mapping,
#    1336                 inputs,
#    1337                 intermediate_steps,
#    1338                 run_manager,
#    1339             )
#    1340         ]
#    1341     )
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain\agents\agent.py:1359, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1356     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1358     # Call the LLM to see what to do.
# -> 1359     output = self._action_agent.plan(
#    1360         intermediate_steps,
#    1361         callbacks=run_manager.get_child() if run_manager else None,
#    1362         **inputs,
#    1363     )
#    1364 except OutputParserException as e:
#    1365     if isinstance(self.handle_parsing_errors, bool):
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain\agents\agent.py:462, in RunnableAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     454 final_output: Any = None
#     455 if self.stream_runnable:
#     456     # Use streaming to make sure that the underlying LLM is invoked in a
#     457     # streaming
#    (...)
#     460     # Because the response from the plan is not a generator, we need to
#     461     # accumulate the output into final output and return that.
# --> 462     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     463         if final_output is None:
#     464             final_output = chunk
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_core\runnables\base.py:3261, in RunnableSequence.stream(self, input, config, **kwargs)
#    3255 def stream(
#    3256     self,
#    3257     input: Input,
#    3258     config: Optional[RunnableConfig] = None,
#    3259     **kwargs: Optional[Any],
#    3260 ) -> Iterator[Output]:
# -> 3261     yield from self.transform(iter([input]), config, **kwargs)
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_core\runnables\base.py:3248, in RunnableSequence.transform(self, input, config, **kwargs)
#    3242 def transform(
#    3243     self,
#    3244     input: Iterator[Input],
#    3245     config: Optional[RunnableConfig] = None,
#    3246     **kwargs: Optional[Any],
#    3247 ) -> Iterator[Output]:
# -> 3248     yield from self._transform_stream_with_config(
#    3249         input,
#    3250         self._transform,
#    3251         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3252         **kwargs,
#    3253     )
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_core\runnables\base.py:2054, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    2052 try:
#    2053     while True:
# -> 2054         chunk: Output = context.run(next, iterator)  # type: ignore
#    2055         yield chunk
#    2056         if final_output_supported:
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_core\runnables\base.py:3211, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    3208     else:
#    3209         final_pipeline = step.transform(final_pipeline, config)
# -> 3211 yield from final_pipeline
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_core\runnables\base.py:1272, in Runnable.transform(self, input, config, **kwargs)
#    1269 final: Input
#    1270 got_first_val = False
# -> 1272 for ichunk in input:
#    1273     # The default implementation of transform is to buffer input and
#    1274     # then call stream.
#    1275     # It'll attempt to gather all input into a single chunk using
#    1276     # the `+` operator.
#    1277     # If the input is not addable, then we'll assume that we can
#    1278     # only operate on the last chunk,
#    1279     # and we'll iterate until we get to the last chunk.
#    1280     if not got_first_val:
#    1281         final = ichunk
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_core\runnables\base.py:5299, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5293 def transform(
#    5294     self,
#    5295     input: Iterator[Input],
#    5296     config: Optional[RunnableConfig] = None,
#    5297     **kwargs: Any,
#    5298 ) -> Iterator[Output]:
# -> 5299     yield from self.bound.transform(
#    5300         input,
#    5301         self._merge_configs(config),
#    5302         **{**self.kwargs, **kwargs},
#    5303     )
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_core\runnables\base.py:1290, in Runnable.transform(self, input, config, **kwargs)
#    1287             final = ichunk
#    1289 if got_first_val:
# -> 1290     yield from self.stream(final, config, **kwargs)
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_core\language_models\llms.py:571, in BaseLLM.stream(self, input, config, stop, **kwargs)
#     564 except BaseException as e:
#     565     run_manager.on_llm_error(
#     566         e,
#     567         response=LLMResult(
#     568             generations=[[generation]] if generation else []
#     569         ),
#     570     )
# --> 571     raise e
#     572 else:
#     573     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_core\language_models\llms.py:555, in BaseLLM.stream(self, input, config, stop, **kwargs)
#     553 generation: Optional[GenerationChunk] = None
#     554 try:
# --> 555     for chunk in self._stream(
#     556         prompt, stop=stop, run_manager=run_manager, **kwargs
#     557     ):
#     558         yield chunk.text
#     559         if generation is None:
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_community\llms\ollama.py:479, in Ollama._stream(self, prompt, stop, run_manager, **kwargs)
#     472 def _stream(
#     473     self,
#     474     prompt: str,
#    (...)
#     477     **kwargs: Any,
#     478 ) -> Iterator[GenerationChunk]:
# --> 479     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     480         if stream_resp:
#     481             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_community\llms\ollama.py:192, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     184 def _create_generate_stream(
#     185     self,
#     186     prompt: str,
#    (...)
#     189     **kwargs: Any,
#     190 ) -> Iterator[str]:
#     191     payload = {"prompt": prompt, "images": images}
# --> 192     yield from self._create_stream(
#     193         payload=payload,
#     194         stop=stop,
#     195         api_url=f"{self.base_url}/api/generate",
#     196         **kwargs,
#     197     )
#
# File e:\Study Space\Python Workspace\Personal Projects\Personal\FinancialChatbot\.venv\Lib\site-packages\langchain_community\llms\ollama.py:271, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     269     else:
#     270         optional_detail = response.text
# --> 271         raise ValueError(
#     272             f"Ollama call failed with status code {response.status_code}."
#     273             f" Details: {optional_detail}"
#     274         )
#     275 return response.iter_lines(decode_unicode=True)
#
# ValueError: Ollama call failed with status code 400. Details: {"error":"\"chevalblanc/embedding:latest\" does not support generate"}
